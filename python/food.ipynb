# %%
class Hotel_Z1:
    hname="Luv_u_foodie"
    branch="Nellore"
    food="veg","non-veg","desserts"
    gst=19
    cart=[]
    account_details={}
    def _init_(self,name,phone,email):
        self.name=name
        self.phone=phone
        self.email=email
        self.concat_acc_details(self.email,self)
   
    #@classmethod
    #def concat_cust_details(cls,acc_no,obj):
     #   cls.cust_details[acc_no]=obj
    @classmethod
    def concat_acc_details(cls,email,obj):
        cls.account_details[email]=obj
    def lets_begin(self):
        n=int(input("choose the option: \n0.login\n1.menu\n2orders\n3.cart\n4.bill\n5.Exit"))
        print("*"*150)
        match n:
            case 0:
                self.login()
            case 1:
                self.menu()
            case 2:
                self.order()
            case 3:
                self.cart_list()
            case 4:
                self.bill()
            case _:
                return
        
    def menu(self):
        def veg():
            print("Vegetarian Menu:")
            print("1. Gobi Manchurian - 70")
            print("2. Veg Manchurian - 60")
            print("3. Paneer Tikka - 100")
            print("4. Baby Corn Manchurian - 120")
            print("5. Veg Biryani - 200")
            print("6. Paneer Biryani - 220")
            print("7. Mushroom Biryani - 260")

        def non_veg():
            print("Non-Vegetarian Menu:")
            print("1. Chicken 65 - 90")
            print("2. Chicken Lollipop - 120")
            print("3. Chicken Tikka - 150")
            print("4. Keema Samosa - 200")
            print("5. Chicken Biryani - 300")
            print("6. Mutton Biryani - 360")
            print("7. Fish Fried Biryani - 350")

        def desserts():
            print("Desserts Menu:")
            print("1. Baked Desserts - 60")
            print("2. Frozen Desserts - 150")
            print("3. Dessert Drinks - 90")
            print("4. Cold Desserts - 120")
            print("5. Fried Desserts - 100")
            print("6. Puddings - 90")
            print("7. Cobblers - 80")
        veg()
        non_veg()
        desserts()
    def order(self):
        n=int(input("choose the option: \n0.vegetarian menu\n1.non-vegetarian\n2.desserts\n3.Exit"))
        print("-"*150)
        match n:
            case 0:
                m=int(input("choose the option: \n0.Vegetarian Menu\n1.Gobi manchurian\n2.veg manchurian\n3.paneer Tikka\n4.Baby corn Manchurian\n5.veg biriyani\n6.paneer biriyani\n7.mushroom biriyani \n8.Exit"))
                print("*"*150)
                match m:
                    case 0:
                        self.veg()
                    case 1:
                        self.cart_list("Gobi manchurian",70)
                    case 2:
                        self.cart_list("veg manchurian" ,60)
                    case 3:
                       self.cart_list("paneer Tikka",100)
                    case 4:
                       self.cart_list("Baby corn Manchurian",120)
                    case 5:
                      self.cart_list("veg biriyani",200)
                    case 6:
                        self.cart_list("paneer biriyani",220)
                    case 7:
                        self.cart_list("mushroom biriyani ",260)
                    case _:
                        return
            case 1:
                o=int(input("choose the option: \n0.Non Vegetarian Menu\n1.chicken 65\n2. chicken lolipop\n3.chicken tikka\n4.keema samosa\n5.chicken biriyani\n6.mutton biriyani\n7.fish fried biriyani \n8.Exit"))
                print("*"*150)
                match o:
                    case 0:
                        self.non_veg()
                    case 1:
                       self.cart_list("Non Vegetarian Menu",90)
                    case 2:
                        self.cart_list("chicken 65",120)
                    case 3:
                        self.cart_list("chicken lolipop",150)
                    case 4:
                        self.cart_list("chicken tikka",200)
                    case 5:
                       self.cart_list("keema samosa",300)
                    case 6:
                       self.cart_list("chicken biriyani",360)
                    case 7:
                        self.cart_list("mutton biriyani",350)
                    case 8:
                        self.cart_list("fish fried biriyani",350)
                    case _:
                        return
            case 2:
                p=int(input("choose the option: \n0.desserts menu\n1.Baked Desserts\n2.frozen Dessert\n3.Dessert Drinks\n4.Cold Desserts\n5.Fried Desserts\n6.puddings\n7.Custards\n8.Exit"))
                print("*"*150)
                match p:
                    case 0:
                        self.desserts()
                    case 1:
                      self.cart_list("Baked Desserts",60)
                    case 2:
                       self.cart_list("frozen Dessert",150)
                    case 3:
                     self.cart_list("Dessert Drinks",90)
                    case 4:
                       self.cart_list("Cold Desserts",120)
                    case 5:
                        self.cart_list("Fried Desserts",100)
                    case 6:
                        self.cart_list("puddings",90)
                    case 7:
                       self.cart_list("Custards",80)
                       
                    case _:
                        return
    def cart_list(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        print(f"{quantity} {item} added to cart.")

    def display_cart(self):
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            for item in self.cart:
                print(f"{item['quantity']} x {item['item']} - ${item['price']} each")
    
    
    
    def login(self):
        login_id=input("Enter the email id:")
        password=int(input("Enter the phn num:"))
        if login_id in self.account_details and self.account_details[login_id].phone == password:
            #self = cls.account_details[login_id]
            self.lets_begin()
        #print(self.email)
        else:
            print("Invalid login id or password")
        
        
obj=Hotel_Z1("doremon",8712316628,"doremon@gmail.com")
obj1=Hotel_Z1("sinchan",9123007895,"sinchan@gmail.com")
print(obj._dict_)
print(obj1._dict_)
obj.lets_begin()
#obj.order()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sravani\OneDrive\Documents\GitHub\SRAVANI\python\food.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=163'>164</a>         #print(self.email)
#     <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=164'>165</a>         else:
#     <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=165'>166</a>             print("Invalid login id or password")
# --> <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=168'>169</a> obj=Hotel_Z1("doremon",8712316628,"doremon@gmail.com")
#     <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=169'>170</a> obj1=Hotel_Z1("sinchan",9123007895,"sinchan@gmail.com")
#     <a href='vscode-notebook-cell:/c%3A/Users/sravani/OneDrive/Documents/GitHub/SRAVANI/python/food.ipynb#W0sZmlsZQ%3D%3D?line=170'>171</a> print(obj._dict_)
#
# TypeError: Hotel_Z1() takes no arguments

# %%
class food:
    hotelname="tinntava"
    adress="musapet"
    res_id=1234
    cart=[]
    details={}
    def __init__(self,name,email,phone):
        self.name=name
        self.email=email
        self.phone=phone
        self.account_details(self.email,self)
    @classmethod
    def account_details(cls,email,obj):
        cls.details[email]=obj
    
    def lets_start(self):
        n=int(input("choose the option:\n0.login\n1.menu\n2.order\n3.cart\n4.bill\n5.exit"))
        print("-"*100)
        match n:
            case 0:
                self.logincustomer()
            case 1:
                self.hotelmenu()
            case 2:
                self.placeorder()
            case 3:
                self.addtocart()
            case 4:
                self.bill()
            case _:
                return
        return self.lets_start()
    def hotelmenu(self):
        def veg():
            print('paneer Briyani')
            print('kaju paneer')
            print('sizziling paneer')
            print('mixed veg dum briyani')
            print('gobi rice')
        def nonveg():
            print('chicken dum briyani')
            print('fish briyani')
            print('prawns briyani')
            print('mutton special briyani')
            print('egg briyani')
        def beverges():
            print("water")
            print("orange juice")
            print("soda")
            print("wine")
            print("blood")
        veg()
        nonveg()
        beverges()

    def placeorder(self):
        n=int(input("choose the option:\n1.veg\n2.nonveg\n3.beverges\n4.exit"))
        match n:
            case 1:
                f=int(input("choose the opition:\n1.paneer Briyani\n2.kaju paneer\n3.sizziling paneer\n4.mixed veg dum briyani\n5.gobi rice\n6.exit"))
                match f:
                    case 1:
                        self.addtocart("panner Briyani",250)
                    case 2:
                        self.addtocart("kaju panner",120)
                    case 3:
                        self.addtocart("sizziling paneer",200)
                    case 4:
                        self.addtocart("mixed veg dum briyani",300)
                    case 5:
                        self.addtocart("gobi rice",100)
                    case _:
                        return
            case 2:
                f=int(input("choose options:\n1.chicken dum briyani\n2.fish briyani\n3.prawns briyani\n4.mutton special briyani\n5.egg briyani\n6.exit"))
                match f:
                    case 1:
                        self.addtocart("chicken dum briyani",250)
                    case 2:
                        self.addtocart("fish briyani",400)
                    case 3:
                        self.addtocart("prawns briyani",350)
                    case 4:
                        self.addtocart("mutton special briyani",300)
                    case 5:
                        self.addtocart("egg briyani",150) 
                    case _:
                        return
            case 3:
                f=int(input("choose the options:1.\nwater\n2.orange juice\n3.soda\n4.wine\n5.blood\n6.exit"))
                match f:
                    case 1:
                        self.addtocart("water",20)
                    case 2:
                        self.addtocart("orange juicie",50)
                    case 3:
                        self.addtocart("soda",30)
                    case 4:
                        self.addtocart("wine",400)
                    case 5:
                        self.addtocart("blood",350)
                    case _:
                        return
        #placeorder(self)
    def addtocart(self, item, price):
        quantity = int(input(f"Enter quantity for {item}: "))
        self.cart.append({"item": item, "price": price, "quantity": quantity})
        print(f"{quantity} {item} added to cart.") 

    #def display_cart(self):
        if not self.cart:
            print("Your cart is empty.")
        else:
            print("Your Cart:")
            
            for item in self.cart:
                print(f"{item['quantity']}*  {item['item']} ,${item['price']}= ${item['price']*item['quantity']} ")
                # r+=item['price']*item['quantity']
                # print('total bill is:',r)
                # print("Thank you for dining")
    def bill(self):
        total_amt=0
        if not self.cart:
            print("Your Cart is Empty. Bill Not Generated")
            return
        else:
            print("Your Bill")
            print("-------------------------------------------------------")
            print("Item\t\t\t Quantity\t\t Price")
            print("-------------------------------------------------------")
            gst=20
            for item in self.cart:
                item_name=item['item']
                quantity=item['quantity']
                price=item['price']
                item_total=quantity*price+gst
                total_amt+=item_total
                print(f"{item_name}\t\t\t{quantity}\t\t\tRs{item_total}")
                print("--------------------------------------------------------")
                print(f"Total Amount: Rs{item_total}")
                print("-------------------------------------------------------")
                print("Thank You For Ordering Enjoy the Food!")
        
       
    def logincustomer(self):
        regid=input("enter the email")
        password=int(input("enterm the phone number"))
        if regid in self.details and self.details[regid].phone==password:
            print("login successfull")
            self.lets_start()

        else:
            print("enter correct email or password")

obj=food("sravani","chittu@gmail.com",1234567890)
obj.lets_start()
obj.placeorder()
# Out:
# ----------------------------------------------------------------------------------------------------
# 2 panner Briyani added to cart.
# Your Cart:
# 2*  panner Briyani ,$250= $500
# ----------------------------------------------------------------------------------------------------
# Your Bill
# -------------------------------------------------------
# Item			 Quantity		 Price
# -------------------------------------------------------
# panner Briyani			2			Rs520
# --------------------------------------------------------
# Total Amount: Rs520
# -------------------------------------------------------
# Thank You For Ordering Enjoy the Food!
# ----------------------------------------------------------------------------------------------------
